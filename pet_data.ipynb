# %%
import pandas as pd

# %%
df
# Out:
#               name  attack  health           trigger  \
# 0              Ant     2.0     2.0             Faint
# 1           Beaver     3.0     2.0              Sell
# 2          Cricket     1.0     3.0             Faint
# 3             Duck     2.0     3.0              Sell
# 4             Fish     2.0     3.0          Level up
# ..             ...     ...     ...               ...
# 258       Sauropod     4.0    12.0  Shop food bought
# 259  Tyrannosaurus     6.0     4.0          End turn
# 260        Lioness     4.0     5.0          End turn
# 261          Tapir     4.0     3.0             Faint
# 262         Walrus     7.0     5.0             Faint
#
#                                                ability  tier
# 0    Give one random friend +1  attack and +1  health.     1
# 1                  Give two random friends +1  attack.     1
# 2                      Summon one 1/1  Zombie Cricket.     1
# 3                           Give shop pets +1  health.     1
# 4          Give two friends +1  attack and +1  health.     1
# ..                                                 ...   ...
# 258             Gain +1  gold. Works 3 times per turn.     6
# 259  Give two tier 5 friends or higher +2  attack a...     6
# 260  Give current and future shop pets +2  attack a...     6
# 261  Summon one level 1 copy of a random friendly p...     6
# 262                   Give one random friend  Peanuts.     6
#
# [263 rows x 6 columns]

# %%
df = pd.read_csv('pet_data.csv')
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(df.loc[df['ability'].str.find('1/1') != -1][['name','ability']])
# Out:
#            name                                            ability
# 2       Cricket                    Summon one 1/1  Zombie Cricket.
# 47          Rat  Summon one 1/1  Dirty Rat up front for the opp...
# 64        Stoat  Summon one level 1 pet from your current tier ...
# 106    Anteater                       Summon one 1/1 level 3  Ant.
# 151        Slug  Summon one 2/2  Smaller Slug that summons one ...
# 242  Pteranodon  Re-summon it behind this as a 1/1. Works 1 tim...
